# %% [markdown]
# # load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #load Data

# %%
df = pd.read_csv(r'/content/Students Performance Dataset.csv')
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %% [markdown]
# #Data Exploration and Cleaning

# %%
df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Mathematics           97.36          40.61        59.61  ...
# 1     Business           97.71          57.27        74.00  ...
# 2  Engineering           99.52          41.84        63.85  ...
# 3  Engineering           90.38          45.65        44.44  ...
# 4           CS           59.41          53.13        61.77  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           62.84      59.8865      F                  10.3
# ...

# %%
df.tail()
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 4995           CS           96.09          45.86        45.63  ...
# 4996  Mathematics           96.30          78.67        47.42  ...
# 4997           CS           89.94          50.84        65.83  ...
# 4998  Engineering           99.09          55.44        57.45  ...
# 4999  Mathematics           90.33          93.29        88.42  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# ...

# %%
df.sample(3)
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 4115      S5115       John     Davis  student4115@university.com    Male   21
# 2666      S3666       Liam  Williams  student2666@university.com  Female   24
# 1777      S2777       John  Williams  student1777@university.com  Female   19
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 4115           CS           85.76          45.90        47.74  ...
# 2666           CS           62.57          84.61        99.13  ...
# 1777  Engineering           84.42          69.31        65.25  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 4115           73.98       63.754      D                  22.7
# 2666           64.74       75.692      C                  11.6
# 1777           78.52       71.078      C                  28.7
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 4115                          No                      No
# ...

# %%
df.shape
# Out:
# (5000, 23)

# %%
df.describe()
# Out:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     5000.000000    5000.000000  5000.000000
# mean     21.048400       75.356076      70.701924    69.546552
# std       1.989786       14.392716      17.436325    17.108996
# min      18.000000       50.010000      40.000000    40.010000
# 25%      19.000000       62.945000      55.707500    54.697500
# 50%      21.000000       75.670000      70.860000    69.485000
# 75%      23.000000       87.862500      85.760000    83.922500
# max      24.000000      100.000000      99.990000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      5000.000000  5000.000000          5000.000000      5000.00000
# mean         74.956320    74.836214            49.963720        74.78305
# std          14.404287    14.423848            28.989785        14.54243
# min          50.000000    50.000000             0.000000        50.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              5000 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             5000 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
df.isnull()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Projects_Score  \
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                       0
# First_Name                       0
# Last_Name                        0
# Email                            0
# Gender                           0
# Age                              0
# Department                       0
# Attendance (%)                   0
# Midterm_Score                    0
# Final_Score                      0
# Assignments_Avg                  0
# Quizzes_Avg                      0
# Participation_Score              0
# Projects_Score                   0
# Total_Score                      0
# Grade                            0
# Study_Hours_per_Week             0
# Extracurricular_Activities       0
# Internet_Access_at_Home          0
# Parent_Education_Level        1025
# Family_Income_Level              0
# Stress_Level (1-10)              0
# Sleep_Hours_per_Night            0
# dtype: int64

# %%
d = df.isnull().sum()
d [d > 0]
# Out:
# Parent_Education_Level    1025
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap = "Blues")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# First_Name                    0
# Last_Name                     0
# Email                         0
# Gender                        0
# Age                           0
# Department                    0
# Attendance (%)                0
# Midterm_Score                 0
# Final_Score                   0
# Assignments_Avg               0
# Quizzes_Avg                   0
# Participation_Score           0
# Projects_Score                0
# Total_Score                   0
# Grade                         0
# Study_Hours_per_Week          0
# Extracurricular_Activities    0
# Internet_Access_at_Home       0
# Parent_Education_Level        0
# Family_Income_Level           0
# Stress_Level (1-10)           0
# Sleep_Hours_per_Night         0
# dtype: int64

# %%
d = df.isnull().sum()
d [d > 0]
# Out:
# Series([], dtype: int64)

# %%
sns.heatmap(df.isnull(),cmap = "Blues")
plt.show()

# %%
len(df)
# Out:
# 3975

# %%
def detect_outliers_iqr(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = dataframe[(dataframe[column] < lower_bound) | (dataframe[column] > upper_bound)]
    return outliers

# Apply outlier detection to all numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns
outlier_counts = {col: len(detect_outliers_iqr(df, col)) for col in numeric_columns}

for col, count in outlier_counts.items():
    print(f"Column {col} contains {count} outlier values.")

df_cleaned = df.copy()
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_cleaned = df_cleaned[(df_cleaned[col] >= lower_bound) & (df_cleaned[col] <= upper_bound)]

print("\nOutliers removed, dataset size after cleaning:", df_cleaned.shape)
# Out:
# Column Age contains 0 outlier values.
# Column Attendance (%) contains 0 outlier values.
# Column Midterm_Score contains 0 outlier values.
# Column Final_Score contains 0 outlier values.
# Column Assignments_Avg contains 0 outlier values.
# Column Quizzes_Avg contains 0 outlier values.
# Column Participation_Score contains 0 outlier values.
# Column Projects_Score contains 0 outlier values.
# Column Total_Score contains 4 outlier values.
# Column Study_Hours_per_Week contains 0 outlier values.
# Column Stress_Level (1-10) contains 0 outlier values.
# Column Sleep_Hours_per_Night contains 0 outlier values.
#
# Outliers removed, dataset size after cleaning: (3971, 23)

# %% [markdown]
# #Data Analysis

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df_cleaned['Department'], y=df_cleaned['Final_Score'], palette="coolwarm")
plt.title("Final Exam Scores by Department")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-0133b1361230>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_cleaned['Department'], y=df_cleaned['Final_Score'], palette="coolwarm")

# %%
plt.figure(figsize=(6,6))
df_cleaned['Gender'].value_counts().plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.title("Gender Distribution Among Students")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df_cleaned["Study_Hours_per_Week"], y=df["Total_Score"], marker="o", color="purple")
plt.title("Study Hours vs. Total Score")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_cleaned["Stress_Level (1-10)"], y=df_cleaned["Sleep_Hours_per_Night"], color="red")
plt.title("Stress Level vs. Sleep Hours per Night")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_cleaned["Final_Score"], bins=20, kde=True, color="blue")
plt.title("Distribution of Final Exam Scores")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df_cleaned['Family_Income_Level'], y=df_cleaned['Total_Score'], palette="magma")
plt.title("Family Income Level vs. Academic Performance")
plt.show()
# Out:
# <ipython-input-29-f1a32392bfe5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_cleaned['Family_Income_Level'], y=df_cleaned['Total_Score'], palette="magma")

# %%
plt.figure(figsize=(6,6))
df_cleaned['Internet_Access_at_Home'].value_counts().plot.pie(autopct='%1.1f%%', colors=['#99ff99','#ffcc99'])
plt.title("Internet Access at Home")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df_cleaned["Gender"], y=df_cleaned["Total_Score"], marker="o", color="darkblue")
plt.title("Comparison of Academic Performance Between Genders")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_cleaned["Sleep_Hours_per_Night"], y=df_cleaned["Total_Score"], color="green")
plt.title("Impact of Sleep Hours on Academic Performance")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_cleaned["Attendance (%)"], bins=20, kde=True, color="orange")
plt.title("Attendance Percentage Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df_cleaned['First_Name'], y=df_cleaned['Total_Score'], palette="Blues")
plt.title("Comparison of Individual Student Scores")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-34-6fd65f20515a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_cleaned['First_Name'], y=df_cleaned['Total_Score'], palette="Blues")

# %%
plt.figure(figsize=(6,6))
df_cleaned['Parent_Education_Level'].value_counts().plot.pie(autopct='%1.1f%%', colors=['#ffcc99','#99ff99','#66b3ff'])
plt.title("Parent Education Level Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df_cleaned["Attendance (%)"], y=df_cleaned["Final_Score"], marker="o", color="darkgreen")
plt.title("Attendance Percentage vs. Final Exam Score")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df_cleaned["Projects_Score"], y=df_cleaned["Total_Score"], color="blue")
plt.title("Impact of Project Scores on Total Academic Score")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_cleaned["Participation_Score"], bins=15, kde=True, color="purple")
plt.title("Distribution of Participation Scores Among Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df_cleaned["Department"], y=df_cleaned["Final_Score"], palette="Set2")
plt.title("Distribution of Final Scores by Department")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-39-7a698a2698a8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_cleaned["Department"], y=df_cleaned["Final_Score"], palette="Set2")

# %%
plt.figure(figsize=(10,6))
corr_matrix = df_cleaned[['Study_Hours_per_Week', 'Sleep_Hours_per_Night', 'Stress_Level (1-10)', 'Total_Score']].corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Study Hours, Sleep, Stress Level, and Total Score")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x=df_cleaned["Extracurricular_Activities"], y=df_cleaned["Total_Score"], palette="muted")
plt.title("Impact of Extracurricular Activities on Total Score")
plt.show()
# Out:
# <ipython-input-41-036ade2476d5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df_cleaned["Extracurricular_Activities"], y=df_cleaned["Total_Score"], palette="muted")

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df_cleaned["Parent_Education_Level"], palette="Pastel1")
plt.title("Distribution of Parent Education Levels")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-42-95946003f3c5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_cleaned["Parent_Education_Level"], palette="Pastel1")

# %%
plt.figure(figsize=(8,6))
sns.regplot(x=df_cleaned["Quizzes_Avg"], y=df_cleaned["Total_Score"], scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title("Impact of Quiz Average on Total Score")
plt.show()
